# %%
import random 
 
maxTicketsAvailable = int(input("Enter the maximum tickets available "))
 
participants = []
 
for temp in range(maxTicketsAvailable):
  st = "Enter the participants name - "+str(temp + 1) + " - "
  name = input(st)
  participants.append(name)
 
  print("All our participants - ",participants)
 
  n = random.randint(0,maxTicketsAvailable - 1)
  participants[n]
# Out:
# Enter the maximum tickets available 3
# Enter the participants name - 1 - stone
# All our participants -  ['stone']
# Enter the participants name - 2 - paper
# All our participants -  ['stone', 'paper']
# Enter the participants name - 3 - scissor
# All our participants -  ['stone', 'paper', 'scissor']

# %%
userdict = {
    "Name" : "ANABEL"
    "NUMBER1": "9940245682"
    "EMAIL ID" : "anabelfdo@gmail.com"
    "NICK-NAME" : "ANU"
}

# %%
howManyContact = 1

contactdict = {}

for i in range(howManyContact):
  name = input("Enter Name ")
  number1 = input("Enter number1 ")
  emailid = input("Enter emailid ")
  nickname = input("Enter nickname ")
# Out:
# Enter Name ANABEL
# Enter number1 9940245682
# Enter emailid anabelfdo@gmail.com
# Enter nickname ANU

# %%
#Assignment 3 
 #To learn about in built functions of Python objects
 #job done Saikiran sir

# %%
# Assignment 4
# The Altitude for plane to land is 1000ft
# If it is less than 1000ft, ask pilot to land plane
# If it is more than that but less than 5000ft,ask pilot to come down to 1000ft
# Else If it is more than 5000ft, ask pilot to go around and try later

# %%
altitude = int(input("Enter Altitude =  "))

if altitude <= 1000 :
   print("land the plane ") 
elif altitude > 1000 and altitude < 5000:
  print("come down to 1000 ")
else:
  print ("go around and try later")
# Out:
# Enter Altitude =  1000
# land the plane

# %%
altitude = int(input("Enter Altitude =  "))

if altitude <= 1000 :
   print("land the plane ") 
elif altitude > 1000 and altitude < 5000:
  print("come down to 1000 ")
else:
  print ("go around and try later")
# Out:
# Enter Altitude =  4550
# come down to 1000

# %%
altitude = int(input("Enter Altitude =  "))

if altitude <= 1000 :
   print("land the plane ") 
elif altitude > 1000 and altitude < 5000:
  print("come down to 1000 ")
else:
  print ("go around and try later")
# Out:
# Enter Altitude =  6000
# go around and try later
